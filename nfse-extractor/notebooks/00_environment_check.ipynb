# %% [markdown]
# # Environment Check
#
# Use this notebook only for environment setup and orchestration.
# Import reusable logic from `src/`; do not implement business logic here.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
from observability.environment_report import collect_environment_report, format_environment_report

report = collect_environment_report()
print(format_environment_report(report))
